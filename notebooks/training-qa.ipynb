# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/philazar/Desktop/march-madness/data/data-2022/model-dev/training/raw_feats_2022_03_07.csv')

# %%
df.head()
# Out:
#    Season  TeamID  tourn_seed     AP         KPK    MAS    MOR         NET  \
# 0    2003    1421          16  250.4  250.400000  265.0  277.0  250.400000
# 1    2003    1112           1    2.0    2.571429    3.0    4.0    2.571429
# 2    2003    1113          10   31.6   31.600000   40.0   22.0   31.600000
# 3    2003    1141          11   45.6   45.600000   36.0   50.0   45.600000
# 4    2003    1143           8   37.2   37.200000   30.0   43.0   37.200000
#
#      POM    RPI  ...  close_win_perc  win_perc_l10       oppg  pythag_wins  \
# 0  273.0  186.0  ...        0.625000           0.5  78.448276     0.247168
# 1    3.0    2.0  ...        0.727273           0.9  70.250000     0.902098
# 2   32.0   32.0  ...        0.454545           0.6  69.172414     0.745981
# 3   50.0   44.0  ...        0.800000           0.9  73.241379     0.715142
# 4   40.0   33.0  ...        0.800000           0.6  69.758621     0.679953
#
# ...

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

df.describe()
# Out:
#             Season       TeamID   tourn_seed           AP          KPK  \
# count  1203.000000  1203.000000  1203.000000  1203.000000  1203.000000
# mean   2011.643392  1294.453034     8.728180    54.093134    53.751912
# std       5.272761   106.057005     4.671943    55.538894    54.592315
# min    2003.000000  1101.000000     1.000000     1.000000     1.000000
# 25%    2007.000000  1209.000000     5.000000    17.000000    17.547619
# 50%    2012.000000  1294.000000     9.000000    35.000000    34.500000
# 75%    2016.000000  1393.000000    13.000000    68.333333    68.000000
# max    2021.000000  1463.000000    16.000000   290.333333   287.000000
#
#                MAS          MOR          NET          POM          RPI  \
# count  1203.000000  1203.000000  1203.000000  1203.000000  1203.000000
# mean     52.368307    58.887781    54.683266    56.904406    50.250732
# std      53.103074    60.302026    55.401362    58.830363    49.565722
# ...

# %%
df.loc[df['pythag_wins'] > .97]
# Out:
#      Season  TeamID  tourn_seed   AP  KPK  MAS  MOR    NET  POM   RPI  SAG  \
# 415    2015    1246           1  1.0  1.0  1.0  2.0  1.125  1.0  1.00  1.0
# 484    2017    1211           1  2.0  2.0  1.0  3.0  2.500  1.0  8.00  1.0
# 554    2019    1211           1  4.0  3.0  9.0  2.0  2.000  2.0  3.75  5.0
#
#      USA  avg_rank_c  avg_rank_l31  avg_rank_l61  avg_rank_l91  \
# 415  1.0       1.125         1.125         1.125      1.142857
# 484  2.0       2.500         2.375         4.750      8.250000
# 554  3.0       3.750         1.750         3.625      4.750000
#
#      rank_l31_delta  rank_l61_delta  rank_l91_delta  avg_rank_pre  \
# 415        1.000000        1.000000        1.000000         4.125
# 484        0.950000        1.900000        1.900000        18.375
# 554        0.466667        0.966667        0.966667         5.750
#
#      avg_rank_exp  conf_champ  major_conf  year_trend  win_perc        ppg  \
# ...

# %%
teams_df = pd.read_csv('/Users/philazar/Desktop/march-madness/data/data-2022/MDataFiles_Stage1/MTeams.csv')

# %%
teams_df.loc[teams_df['TeamID'].isin([1246,1211,1211])]
# Out:
#      TeamID  TeamName  FirstD1Season  LastD1Season
# 110    1211   Gonzaga           1985          2022
# 145    1246  Kentucky           1985          2022

# %%
df.groupby('Season')['TeamID'].nunique()
# Out:
# Season
# 2003    65
# 2004    65
# 2005    65
# 2006    65
# 2007    65
# 2008    65
# 2009    65
# 2010    65
# 2011    68
# 2012    68
# 2013    68
# 2014    68
# 2015    68
# 2016    68
# 2017    68
# 2018    68
# 2019    68
# 2021    67
# Name: TeamID, dtype: int64

# %%
len(df.columns)
# Out:
# 52
